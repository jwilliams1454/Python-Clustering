# %%
# https://towardsdatascience.com/4-simple-tips-for-plotting-multiple-graphs-in-python-38df2112965c
# see chart

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')
# %cd "C:\Users\jwill\Documents\Lumen\QF Personas"
# Out:
# C:\Users\jwill\Documents\Lumen\QF Personas

# %%
QFplot = pd.read_csv("QF_plottest.csv")

# %%
plt.figure(figsize=(30, 80))

ax1 = plt.subplot(12,3,1)
sns.violinplot(y='C_Speed', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,2)
sns.violinplot(y='C_Price', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,3)
sns.violinplot(y='C_Reliability', x='Cluster', data=QFplot, height=3)
ax1 = plt.subplot(12,3,4)
sns.violinplot(y='C_Brand', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,5)
sns.violinplot(y='C_Offers', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,6)
sns.violinplot(y='C_Cust_Serv', x='Cluster', data=QFplot, height=3)

ax1 = plt.subplot(12,3,7)
sns.violinplot(y='M_Billing', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,8)
sns.violinplot(y='M_Cust_Serv', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,9)
sns.violinplot(y='M_Tech_Support', x='Cluster', data=QFplot, height=3)
ax1 = plt.subplot(12,3,10)
sns.violinplot(y='M_Upgrade', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,11)
sns.violinplot(y='M_Devices', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,12)
sns.violinplot(y='M_Troubleshoot', x='Cluster', data=QFplot, height=3)

ax1 = plt.subplot(12,3,13)
sns.violinplot(y='M_Security', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,14)
sns.violinplot(y='H_Friend', x='Cluster', data=QFplot, height=3)
ax1 = plt.subplot(12,3,15)
sns.violinplot(y='H_Call', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,16)
sns.violinplot(y='H_Videos', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,17)
sns.violinplot(y='H_Chat', x='Cluster', data=QFplot, height=3)

ax1 = plt.subplot(12,3,18)
sns.violinplot(y='H_QF_site', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,19)
sns.violinplot(y='H_Web', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,20)
sns.violinplot(y='I_Education', x='Cluster', data=QFplot, height=3)
ax1 = plt.subplot(12,3,21)
sns.violinplot(y='I_Work', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,22)
sns.violinplot(y='I_Smart_home', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,23)
sns.violinplot(y='I_Entertainment', x='Cluster', data=QFplot, height=3)

ax1 = plt.subplot(12,3,24)
sns.violinplot(y='I_Social', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,25)
sns.violinplot(y='I_Fitness', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,26)
sns.violinplot(y='I_Security', x='Cluster', data=QFplot, height=3)
ax1 = plt.subplot(12,3,27)
sns.violinplot(y='Set_forget', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,28)
sns.violinplot(y='Optimize', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,29)
sns.violinplot(y='Self_troubleshoot', x='Cluster', data=QFplot, height=3)

ax1 = plt.subplot(12,3,30)
sns.violinplot(y='ISP_Troubleshoot', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,31)
sns.violinplot(y='TC_Customer', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,32)
sns.violinplot(y='TC_Worry', x='Cluster', data=QFplot, height=3)
ax1 = plt.subplot(12,3,33)
sns.violinplot(y='TC_Advise', x='Cluster', data=QFplot, height=3)
ax2 = plt.subplot(12,3,34)
sns.violinplot(y='TC_Embarassed', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,35)
sns.violinplot(y='Total_MonthlyGig', x='Cluster', data=QFplot, height=3)
ax3 = plt.subplot(12,3,36)
sns.violinplot(y='SF_total_30day_gig', x='Cluster', data=QFplot, height=3)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='SF_total_30day_gig'>

# %%
QFplot
# Out:
#      C_Speed  C_Price  C_Reliability  C_Brand  C_Offers  C_Cust_Serv  \
# 0          7        7              7        7         7            7
# 1          7        7              7        6         6            6
# 2          7        7              7        5         6            7
# 3          7        7              7        1         5            7
# 4          7        7              6        2         2            6
# ..       ...      ...            ...      ...       ...          ...
# 995        7        7              7        6         7            7
# 996        5        6              6        4         4            7
# 997        7        7              7        7         7            7
# 998        7        7              7        4         6            7
# 999        6        5              6        2         4            7
#
#      M_Billing  M_Cust_Serv  M_Tech_Support  M_Upgrade  ...  PCA5_KM6  \
# ...
